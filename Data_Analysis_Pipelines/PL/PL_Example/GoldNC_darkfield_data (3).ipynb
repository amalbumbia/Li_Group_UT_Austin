# %% [markdown]
# # Darkfield Data mAuNC

# %%
# !pip install sif_parser
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# # Imports

# %%
import sif_parser
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# This notebook refers specifically to the monolayer TMD sample used to survey
# the correlation between exciton and plasmonic resonances in emission enhancement. This is from when the sample had only gold nanocubes on its surface.

# %% [markdown]
# # Raw Images

# %%
with open('50ms_x50_DF.png', 'rb') as f:
    image_data = f.read()
image_path = '50ms_x50_DF.png'
image = mpimg.imread(image_path)
x = np.arange(image.shape[1] + 1)
y = np.arange(image.shape[0] + 1)
plt.imshow(image, cmap='gray')
plt.show()

with open('50ms_x50_LF.png', 'rb') as f:
    image_data = f.read()
image_path = '50ms_x50_LF.png'
image = mpimg.imread(image_path)
x = np.arange(image.shape[1] + 1)
y = np.arange(image.shape[0] + 1)
plt.imshow(image, cmap='gray')
plt.show()

with open('150ms_x100_DF.png', 'rb') as f:
    image_data = f.read()
image_path = '150ms_x100_DF.png'
image = mpimg.imread(image_path)
x = np.arange(image.shape[1] + 1)
y = np.arange(image.shape[0] + 1)
plt.imshow(image, cmap='gray')
plt.show()

with open('150ms_x100_DF_marked..png', 'rb') as f:
    image_data = f.read()
image_path = '150ms_x100_DF_marked..png'
image = mpimg.imread(image_path)
x = np.arange(image.shape[1] + 1)
y = np.arange(image.shape[0] + 1)
plt.imshow(image, cmap='gray')
plt.show()

# %% [markdown]
# # Light Field Source

# %% [markdown]
# Image of source spectrum

# %%
source, info = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])
wavelengths = sif_parser.utils.extract_calibration(info)
info
plt.pcolor(wavelengths, range(200), source[0])

# %% [markdown]
# Source plot

# %%
int_source = source[0].mean(axis=0)
plt.plot(wavelengths, int_source)

# %% [markdown]
# # Point 1

# %%
data, info = sif_parser.np_open('10sec_pt1.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688675678),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt1.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 1 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 2

# %%
data, info = sif_parser.np_open('10sec_pt2.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688675910),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt2.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 2 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 3

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt3_zeroorder.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt3.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688676176),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt3.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 3 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 4

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt4_zeroorder.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt4.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688676821),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt4.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 4 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 5

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt5_zeroorder.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt5.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688677073),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt5.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 5 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 6

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt6_zeroorder.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt6.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688677695),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt6.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 6 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 7

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt7_zeroorder.sif')
datazc, _ = sif_parser.np_open('1sec_pt7_zeroorder_closedslit.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')
plt.subplot(2,1,2)
plt.pcolor(range(200), range(dataz.shape[1]), datazc[0,:, 750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt7.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688677931),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt7.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 7 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 8

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt8_zeroorder.sif')
datazc, _ = sif_parser.np_open('1sec_pt8_zeroorder_closedslit.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')
plt.subplot(2,1,2)
plt.pcolor(range(200), range(dataz.shape[1]), datazc[0,:, 750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt8.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688678382),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt8.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 8 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 9

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt9_zeroorder.sif')
datazc, _ = sif_parser.np_open('1sec_pt9_zeroorder_closedslit.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')
plt.subplot(2,1,2)
plt.pcolor(range(200), range(dataz.shape[1]), datazc[0,:, 750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt9.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688678701),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt9.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 9 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 10

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt10_zeroorder.sif')
datazc, _ = sif_parser.np_open('1sec_pt10_zeroorder_closedslit.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')
plt.subplot(2,1,2)
plt.pcolor(range(200), range(dataz.shape[1]), datazc[0,:, 750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt10.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688679217),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt10.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 10 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 11

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt11_zeroorder.sif')
datazc, _ = sif_parser.np_open('1sec_pt11_zeroorder_closedslit.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')
plt.subplot(2,1,2)
plt.pcolor(range(200), range(dataz.shape[1]), datazc[0,:, 750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt11.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688679507),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt11.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 11 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 12

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt12_zeroorder.sif')
datazc, _ = sif_parser.np_open('1sec_pt12_zeroorder_closedslit.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')
plt.subplot(2,1,2)
plt.pcolor(range(200), range(dataz.shape[1]), datazc[0,:, 750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt12.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688679888),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt12.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 12 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])

# %% [markdown]
# # Point 13

# %% [markdown]
# Zero order images

# %%
dataz, _ = sif_parser.np_open('1sec_pt13_zeroorder.sif')
datazc, _ = sif_parser.np_open('1sec_pt13_zeroorder_closedslit.sif')
plt.subplot(2,1,1)
plt.pcolor(range(200), range(dataz.shape[1]), dataz[0,:,750:950], cmap='gray')
plt.subplot(2,1,2)
plt.pcolor(range(200), range(dataz.shape[1]), datazc[0,:, 750:950], cmap='gray')

# %%
data, info = sif_parser.np_open('10sec_pt13.sif')
source, _ = sif_parser.np_open('LF_spectrum.sif')
# Fix for weird behaviour for calculating wls due to stich
info['DetectorDimensions'] = (info['size'][0], info['DetectorDimensions'][1])

# %%
wavelengths = sif_parser.utils.extract_calibration(info)

# %%
info
# Out:
# OrderedDict([('SifVersion', 65567),
#              ('ExperimentTime', 1688680266),
#              ('DetectorTemperature', -999.0),
#              ('ExposureTime', 10.0),
#              ('CycleTime', 10.1155),
#              ('AccumulatedCycleTime', 10.1155),
#              ('AccumulatedCycles', 1),
#              ('StackCycleTime', 10.1155),
#              ('PixelReadoutTime', 3.33333e-07),
#              ('GainDAC', 0.0),
#              ('DetectorType', 'DU970P_BVF \n'),
#              ('DetectorDimensions', (3520, 200)),
#              ('OriginalFilename',
#               b'C:\\Users\\ha24428\\Documents\\20230706_sample1\\10sec_pt13.sif'),
#              ('ShutterTime', (0.0, 0.0)),
#              ('spectrograph', '999'),
#              ('SifCalbVersion', 65540),
#              ('Calibration_data',
#               [399.872131347656, 0.127877235412598, 0.0, 0.0]),
#              ('FrameAxis', b'Wavelength'),
#              ('DataType', b'Counts'),
# ...

# %% [markdown]
# Wavelength spread (point 13 localized at appx y = 100)

# %%
plt.pcolor(wavelengths, range(200), data[0])
